# %% [markdown]
# Q1. Explain what version control is and its importance in software development

# %% [markdown]
# Ans: Version control is a system that tracks changes to code over time. It's essential in software development because it:
#
#   Allows multiple developers to collaborate safely.
#
#    Lets you revert to previous versions if something goes wrong.
#
#    Keeps a history of all changes made.
#
#    Supports branching to develop features or fix bugs independently.
#
# Tools like Git help manage code efficiently, prevent data loss, and improve teamwork.

# %% [markdown]
# Q2. Explain the Git Workflow, including the staging area, working directory, and repository

# %% [markdown]
# Ans: Git workflow involves three main areas:
#
#    Working Directory – where you make code changes.
#
#    Staging Area – where you prepare changes using git add.
#
#   Repository – where changes are permanently saved using git commit.
#
# This process helps track, review, and manage code changes efficiently.

# %% [markdown]
# Q3.Explain what .gitignore is and why it’s important in version control

# %% [markdown]
# Ans:  .gitignore is a file that tells Git which files or folders to ignore.
# It’s important because it:
#
#    Keeps sensitive or unnecessary files out of the repository
#
#    Prevents clutter from temporary or system files
#
#    Ensures only relevant code is tracked and shared
#
# This helps keep the project clean, secure, and efficient.

# %% [markdown]
# Q4.Briefly explain what GitHub is and how it facilitates collaboration and version control also name some
# alternatives to GitHub.

# %% [markdown]
# Ans:  GitHub is an online platform that hosts Git repositories and helps developers collaborate, track changes, and manage code efficiently. It supports features like branching, pull requests, and code reviews.
#
# Alternatives include:
# GitLab
# Bitbucket
# SourceForge
# Azure DevOps

# %% [markdown]
# Q5. Describe the process of contributing to any open-source project on GitHub in a step-by-step manner.

# %% [markdown]
# Ans: Summary: Steps to Contribute to an Open-Source Project on GitHub
#
#   Find a project to contribute to.
#
#   Fork the repository to your GitHub account.
#
#   Clone the fork to your local machine.
#
#   Create a new branch for your changes.
#
#    Make changes to the code.
#
#   Commit and push your changes.
#
#   Open a pull request (PR) on the original repo.
#
#    Respond to feedback if needed.
#
#    Once approved, your changes are merge

# %% [markdown]
# Q6. Deploy Tailwind projects named Youtube, slack, and Gmail clones on GitHub pages and share the
# deployed link of those three. Expected output - Live hosted URL Link of your deployed respective website with
# GitHub pages.
# *Note - For this task, you can use HTML and CSS for now. Tailwind CSS is not required at this stage.

# %% [markdown]
# Ans:Summary: Deploying Projects on GitHub Pages
#
#    Create a GitHub repo for each project (youtube-clone, slack-clone, gmail-clone).
#
#    Upload your HTML & CSS files to each repo.
#
#   Go to Settings → Pages, select main branch and /root folder.
#
#   Save and get the live link.
#
# Expected Output Example
#
#    🔗 YouTube Clone: https://your-username.github.io/youtube-clone/
#
#    🔗 Slack Clone: https://your-username.github.io/slack-clone/
#
#    🔗 Gmail Clone: https://your-username.github.io/gmail-clone/
#
# Replace your-username with your GitHub username.
